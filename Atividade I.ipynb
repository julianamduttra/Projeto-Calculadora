# %%
# PROJETO: Calculadora Analítica
# Objetivo: Realizar operações matemáticas com validação de dados e fluxo contínuo

print("="*30)
print("SISTEMA DE CÁLCULOS ANALÍTICOS")
print("="*30)

while True:
    try:
        # PASSO 1 e 2: Entrada de dados com conversão e proteção contra erros
        num1 = float(input("\nDigite o primeiro número: "))
        num2 = float(input("Digite o segundo número: "))

        # PASSO 4: Menu de Opções (Interface)
        print("\nOPERAÇÕES DISPONÍVEIS:")
        print("1. Soma (+)")
        print("2. Subtração (-)")
        print("3. Multiplicação (*)")
        print("4. Divisão (/)")
        print("5. Sair do Programa")

        opcao = input("\nEscolha uma opção (1-5): ")

        if opcao == '5':
            print("\nEncerrando o sistema... Até logo!")
            break

        # PASSO 3: Processamento das operações
        if opcao == '1':
            resultado = num1 + num2
            simbolo = "+"
        elif opcao == '2':
            resultado = num1 - num2
            simbolo = "-"
        elif opcao == '3':
            resultado = num1 * num2
            simbolo = "*"
        elif opcao == '4':
            if num2 != 0:
                resultado = num1 / num2
                simbolo = "/"
            else:
                print("\n[ERRO] Não é possível dividir por zero!")
                continue
        else:
            print("\n[AVISO] Opção inválida! Tente novamente.")
            continue

        # PASSO 5: Exibição Profissional do Resultado
        print("-" * 20)
        print(f"RELATÓRIO DA OPERAÇÃO:")
        print(f"Cálculo: {num1} {simbolo} {num2}")
        print(f"RESULTADO FINAL: {resultado}")
        print("-" * 20)

    except ValueError:
        # Caso o usuário digite texto onde deveria ser número
        print("\n[ERRO] Por favor, digite apenas números válidos.")

print("\n" + "="*30)
print("PROJETO FINALIZADO COM SUCESSO")
print("="*30)
# Out:
# ...
# SISTEMA DE CÁLCULOS ANALÍTICOS
# ...
#
# Digite o primeiro número: 10
# Digite o segundo número: 2
#
# OPERAÇÕES DISPONÍVEIS:
# 1. Soma (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Sair do Programa
#
# Escolha uma opção (1-5): 1
# --------------------
# RELATÓRIO DA OPERAÇÃO:
# Cálculo: 10.0 + 2.0
# RESULTADO FINAL: 12.0
# --------------------
#
# Digite o primeiro número: 5
# Digite o segundo número: 2
#
# OPERAÇÕES DISPONÍVEIS:
# 1. Soma (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Sair do Programa
#
# Escolha uma opção (1-5): 3
# --------------------
# RELATÓRIO DA OPERAÇÃO:
# Cálculo: 5.0 * 2.0
# RESULTADO FINAL: 10.0
# --------------------
#
# Digite o primeiro número: 5
# Digite o segundo número: 3
#
# OPERAÇÕES DISPONÍVEIS:
# 1. Soma (+)
# 2. Subtração (-)
# 3. Multiplicação (*)
# 4. Divisão (/)
# 5. Sair do Programa
#
# Escolha uma opção (1-5): 2
# --------------------
# RELATÓRIO DA OPERAÇÃO:
# Cálculo: 5.0 - 3.0
# ...
